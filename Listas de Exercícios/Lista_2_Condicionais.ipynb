# %% [markdown]
# **Questão 1 - Par ou ímpar:**
#
# Faça um programa que detecte se o número inserido é par ou ímpar.

# %%
numero=int(input("Insira um número:"))
if numero%2!=0:
    print("O número é ímpar!")
else:
    print("O número é par!")
# Out:
# Insira um número:35
# O número é ímpar!

# %% [markdown]
# **Questão 2 - Hora do voto**
#
# 2022 é ano de eleição para presidência da república e para o governo estadual. Faça um programa que ao digitar a idade, ele diga se a pessoa já pode votar, se é obrigatório ou não.

# %%
idade=int(input('escreva a sua idade:'))
if idade>=16 and idade<18:
  print('A pessoa pode votar, mas não é obrigatório')
elif idade>=18 and idade<70:
  print('A pessoa é obrigada a votar')
else:
  print('A pessoa não precisa votar')
# Out:
# escreva a sua idade:23
# A pessoa é obrigada a votar

# %% [markdown]
# **Questão 3 - Nota:**
#
# Você está no final do semestre, suas notas de P1 e trabalhos foram 3.5 | 7.0 | 4.0. Agora na P2, a depender da sua nota, você:
#
# *   Pega dp direto (média final menor do que 3)
# *   Vai para a reaval (média final maior do que 3 e menor do que 5)
# *   É aprovado direto (média final maior do que 5)
#
# a) Faça um código que receba o input da sua nota P2, calcule sua média final (média simples de todas as notas) e imprima se você foi aprovado ou não dependendo seguindo os critérios estabelecidos.

# %%
nota_final=float(input("Insira a sua nota:"))
soma_notas=3.5+7.0+4.0
media=(nota_final+soma_notas)/4
if media<3:
    print("Você está reprovado com média {}">format(media))
elif media>=3 and media<5:
    print("Você vai para reaval com média {}".format(media))
else:
    print("Você foi aprovado direto com média {}".format(media))
# Out:
# Insira a sua nota:3.5
# Você vai para reaval com média 4.5

# %% [markdown]
# b) Digamos que sua nota da P2 tenha sido 4.0, o que te leva para reaval. Quanto você precisa tirar na reaval para ser aprovado? Lembre-se que a sua nota final é uma média simples entre a média antiga e sua nota na reaval (ela deve ser maior que 5 para você passar).

# %%
soma_notas=3.5+7.0+4.0+4.0
media_2 = soma_notas/4
print(media_2)
nota_reaval=(10-media_2)
print("Você precisa tirar {} na reaval!".format(nota_reaval))

media_2+media
# Out:
# 4.625
# Você precisa tirar 5.375 na reaval!

# %% [markdown]
# c) Agora, as notas tem pesos diferentes. A primeira nota (3.5) tem peso de 15%, a segunda nota, tem peso de 35%, a terceira tem peso de 25% e a sua última nota, 25% também.Refaça o exercío "a", empregando essa mudança.

# %%
nota_final=float(input("Insira a sua nota:"))
soma_notas=((3.5*15)/100)+((7.0*35)/100)+((4.0*25)/100)
media=((nota_final*0.25)+soma_notas)
print(media)
if media<3:
    print("Você está reprovado com média {}">format(media))
elif media>=3 and media<5:
    print("Você vai para reaval com média {}".format(media))
else:
    print("Você foi aprovado direto com média {}".format(media))
# Out:
# Insira a sua nota:5
# 5.225
# Você foi aprovado direto com média 5.225

# %% [markdown]
# **Questão 4 - Como ser da Poli**
#
# Nesse exercício vamos ajudar nossos colegas da Poli com esse esquema. Sua tarefa é escrever esse fluxograma na forma de códigos, trazendo perguntas que pedem inputs e que resultam no output correspondente

# %% [markdown]
# **Ex:** "Deveria?"
#
# **Input:** "Sim"
#
# **Output:** "Ótimo"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inicio = input("Está se movendo?").upper()

if inicio == "NÃO":
  deveria = input("Deveria?").upper()
  if deveria == "NÃO":
    print("Ótimo")
  else:
    print("Lubrificante")
else:
  deveria = input("Deveria?").upper()
  if deveria == "NÃO":
    print("Silver tape!")
  else:
    print("Ótimo")
# Out:
# Está se movendo?sim
# Deveria?sim
# Ótimo

# %% [markdown]
# **Questão 5 - Ler**:
#
# Você descobriu um sebo perto da sua casa e resolve dar uma olhada e encontra muitos títulos interessantes. Mas como você não está nadando em dinheiro, terá que fazer algumas escolhas. Escreva um programa que retorne se você deverá comprar ou não o livro, considerando que ele precisa estar na sua wishlist (nada de comprar por impulso) e o preço do sebo deve ser mais barato do que na internet.

# %% [markdown]
# a) Você deverá comprar Moby Dick?
#
# b) Você deverá comprar Crime e Castigo?
#
# c) Você deverá comprar a Odisseia?

# %%
wishlist = ['Moby Dick', 'Helena', 'A Origem das Espécies', 'Grande Sertão: Veredas', 'Odisseia', 'Rápido e Devagar', 'Sidarta']

precos_sebo = {'Odisseia':50, 'Jane Eyre':61, 'A Divina Comédia': 56, 'Helena':10, 'Moby Dick':55, 'Crime e Castigo':20}
precos_internet = {'Odisseia':30, 'Jane Eyre':32, 'A Divina Comédia': 22, 'Helena':26, 'Moby Dick':145, 'Crime e Castigo':80}


#####SEU CODIGO COMECA AQUI#####
livro = input("Qual livro quero comprar? ")

if precos_sebo['Moby Dick'] < precos_internet['Moby Dick']:
  print('Preço ok')
  if

if livro in wishlist and precos_sebo[livro] < precos_internet[livro]:
  print('Comprar')
else:
  print('Não comprar')
# Out:
# Qual livro quero comprar? Moby Dick
# Comprar

# %% [markdown]
# **Questão 6 - Mercado futuro de festa**
#
# Que as festas da faculdade são patrimônio universitário, todo mundo sabe, mas se a gente for em todas, não há carteira que aguente. Pior é pagar por uma festa agora e não ter grana para uma festa melhor depois. Assim, para lidar com essa volatilidade, você decide aplicar umas jogadas do mercado financeiro e de quebra, escrever uns códigos
#
# Você paga $40 reais para seu amigo. Em troca, ele deverá pagar o seu ingresso para a próxima festa, independente do valor. Se o ingresso for mais caro, você se deu bem, se for mais barato, você se deu mal. Escreva um código que receba o input do valor do próximo ingresso, indique se foi uma operação vantajosa e o quanto você perdeu ou economizou.

# %%
#####SEU CODIGO COMECA AQUI#####
preco_ingresso = int(input('Digite o preço da festa:'))

if preco_ingresso >40:
  print(f'Me dei bem, economizei ${preco_ingresso - 40} reais')
else:
  print(f'Me ferrei, perdi ${40 - preco_ingresso}')
# Out:
# Digite o preço da festa:30
# Me ferrei, perdi $10

# %% [markdown]
# **Questão 7 - Café com pão, café com pão...**
#
# Você foi no Sweden na FEA tomar um café e saiu 254,76 reais. Na hora de efetuar o pagamento, você se deparou com algumas escolhas:
#
# *   Você pode pagar a vista(1x)
# *   Pode parcelar em até 3x com juros de 2,5% (aplicado sobre o valor inicial de 254,76)
# *   Pode parcelar em mais vezes (máximo de 12 parcelas), com juros de 5%
#
# Então faça um programa que calcule o valor total, dependendo da sua escolha, e o valor de cada parcela, caso opte por pagar a prazo.

# %%
escolha1=int(input("1-pagar à vista\n2-parcelar\nEscolha:"))
if escolha1==1:
    print("O valor pago é de R$254,76")
else:
    parcelas=int(input("Insira o número de parcelas que você deseja pagar:"))
    if parcelas<=3:
        valor_pago=254.76*1.025
        valor_parcela = valor_pago / parcelas
        print("O valor pago é de {} com parcelas de {}".format(round(valor_pago,2), round(valor_parcela, 2))) 
    else:
        valor_pago=254.76*1.05
        valor_parcela = valor_pago / parcelas
        print("O valor pago é de {} com parcelas de {}".format(round(valor_pago,2), round(valor_parcela, 2)))
# Out:
# 1-pagar à vista
# 2-parcelar
# Escolha:2
# Insira o número de parcelas que você deseja pagar:12
# O valor pago é de 267.5 com parcelas de 22.29

# %% [markdown]
# b)Agora, calcule quanto você vai pagar por mês, caso o usuário tenha escolhido para parcelar:

# %%
if escolha1==1:
    print("Você pagará R$254,67 em um único mês à vista")
if escolha1==2:
    valor_mes=valor_pago/parcelas
    print("Você pagará {} por mês".format(valor_mes))
# Out:
# Você pagará 22.2915 por mês
